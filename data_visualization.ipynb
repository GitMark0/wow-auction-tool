# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as dates

# %%
monelite_tbl = pd.read_csv('monelite-ore-prices.csv')
monelite_tbl.describe()
# Out:
#         item_id  house     pricemin     priceavg     pricemax   pricestart  \
# count      93.0   93.0    93.000000    93.000000    93.000000    93.000000
# mean   152512.0  187.0   885.860215  1006.161290  1232.440860  1008.451613
# std         0.0    0.0   211.827175   232.540473   791.113586   252.069026
# min    152512.0  187.0   286.000000   555.000000   575.000000   532.000000
# 25%    152512.0  187.0   785.000000   884.000000   935.000000   865.000000
# 50%    152512.0  187.0   893.000000  1014.000000  1070.000000   982.000000
# 75%    152512.0  187.0  1020.000000  1119.000000  1212.000000  1120.000000
# max    152512.0  187.0  1361.000000  1637.000000  7086.000000  1900.000000
#
#           priceend   quantitymin   quantityavg   quantitymax
# count    93.000000     93.000000     93.000000     93.000000
# mean   1006.494624  23666.354839  32659.677419  40946.387097
# std     251.046965   8877.140540   7793.866640   9277.597025
# ...

# %%
monelite_tbl['date'] = pd.to_datetime(monelite_tbl['date'])
monelite_tbl.head()
df = monelite_tbl.set_index('date')
df.plot(x_compat=True)
plt.gca().xaxis.set_major_locator(dates.DayLocator())
plt.gca().xaxis.set_major_formatter(dates.DateFormatter('%d\n\n%a'))
plt.gca().invert_xaxis()
plt.gcf().autofmt_xdate(rotation=0, ha="center")
